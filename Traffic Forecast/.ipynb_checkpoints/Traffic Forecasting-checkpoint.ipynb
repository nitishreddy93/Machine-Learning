# %%
import pandas as pd          
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import Series
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
train=pd.read_csv("Train_SU63ISt.csv")
test=pd.read_csv("Test_0qrQsBZ.csv")
train_original=train.copy()
test_original=test.copy()
train.shape, test.shape
# Out:
# ((18288, 3), (5112, 2))

# %%
train.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
test.head()
# Out:
#       ID          Datetime
# 0  18288  26-09-2014 00:00
# 1  18289  26-09-2014 01:00
# 2  18290  26-09-2014 02:00
# 3  18291  26-09-2014 03:00
# 4  18292  26-09-2014 04:00

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train.dtypes, test.dtypes
# Out:
# (ID           int64
#  Datetime    object
#  Count        int64
#  dtype: object, ID           int64
#  Datetime    object
#  dtype: object)

# %% [markdown]
# Datetime is of object type. So we need to covert it to datetime.

# %%
train['Datetime'] = pd.to_datetime(train.Datetime, format = '%d-%m-%Y %H:%M')
test['Datetime'] = pd.to_datetime(test.Datetime, format = '%d-%m-%Y %H:%M')
train.dtypes, test.dtypes
# Out:
# (ID                   int64
#  Datetime    datetime64[ns]
#  Count                int64
#  dtype: object, ID                   int64
#  Datetime    datetime64[ns]
#  dtype: object)

# %% [markdown]
# Creating columns for the below for EDA:
#     - Year
#     - Month
#     - Day
#     - Hour

# %%
train.loc[:,'year'] = train.Datetime.dt.year
train.loc[:,'month'] = train.Datetime.dt.month
train.loc[:,'day'] = train.Datetime.dt.day
train.loc[:,'hour'] = train.Datetime.dt.hour

# %%
test.loc[:,'year'] = test.Datetime.dt.year
test.loc[:,'month'] = test.Datetime.dt.month
test.loc[:,'day'] = test.Datetime.dt.day
test.loc[:,'hour'] = test.Datetime.dt.hour

# %% [markdown]
# Adding a new column as day of week. This is to do analysis of the traffic during the weekdays and weekends

# %%
train['day_of_week'] = train['Datetime'].dt.dayofweek
train.tail()
# Out:
#           ID            Datetime  Count  year  month  day  hour  day_of_week
# 18283  18283 2014-09-25 19:00:00    868  2014      9   25    19            3
# 18284  18284 2014-09-25 20:00:00    732  2014      9   25    20            3
# 18285  18285 2014-09-25 21:00:00    702  2014      9   25    21            3
# 18286  18286 2014-09-25 22:00:00    580  2014      9   25    22            3
# 18287  18287 2014-09-25 23:00:00    534  2014      9   25    23            3

# %%
test.head()
# Out:
#       ID            Datetime  year  month  day  hour
# 0  18288 2014-09-26 00:00:00  2014      9   26     0
# 1  18289 2014-09-26 01:00:00  2014      9   26     1
# 2  18290 2014-09-26 02:00:00  2014      9   26     2
# 3  18291 2014-09-26 03:00:00  2014      9   26     3
# 4  18292 2014-09-26 04:00:00  2014      9   26     4

# %%
def dayofweek(df):
    if df == 5 or df == 6:
        return 0
    else:
        return 1

train['weekday'] = train.day_of_week.apply(dayofweek)
train.head()
# Out:
#    ID            Datetime  Count  year  month  day  hour  day_of_week  weekday
# 0   0 2012-08-25 00:00:00      8  2012      8   25     0            5        0
# 1   1 2012-08-25 01:00:00      2  2012      8   25     1            5        0
# 2   2 2012-08-25 02:00:00      6  2012      8   25     2            5        0
# 3   3 2012-08-25 03:00:00      2  2012      8   25     3            5        0
# 4   4 2012-08-25 04:00:00      2  2012      8   25     4            5        0

# %% [markdown]
# Drop the ID column as it is of no use.

# %% [markdown]
# Making the Datetime column as the index because for Time series forcasting we need to have the datetime values as the index

# %%
train.index = train.Datetime
train.drop(['Datetime','ID'],axis=1,inplace=True)
train.head()
# Out:
#                      Count  year  month  day  hour  day_of_week  weekday
# Datetime
# 2012-08-25 00:00:00      8  2012      8   25     0            5        0
# 2012-08-25 01:00:00      2  2012      8   25     1            5        0
# 2012-08-25 02:00:00      6  2012      8   25     2            5        0
# 2012-08-25 03:00:00      2  2012      8   25     3            5        0
# 2012-08-25 04:00:00      2  2012      8   25     4            5        0

# %% [markdown]
# Plotting the Time series to see the Trend of the Time Series.
#
# We can visualize whether there is an increasing of decreasing trend

# %%
plt.figure(figsize=(15,5))
ts = train['Count']
plt.plot(ts)

# %% [markdown]
# Looking at the above Time Series we can see the Trend of the Time series.
# Observations:
# - We can clearly see that there is an increasing Trend in the Time Series.
# - On some days there is a surge in the count. This may be due to some special occations on those particular days
# - We can also notice that the Count of the people using this service is increasing increasing which is a good sign

# %% [markdown]
# Now we will do some in depth analysis of the behaviour of the Time Series.
#
# This will be done by using the newly created columns i.e year, month, days, hours, days of week, and weekdays/weekends.

# %% [markdown]
# #### 1) Yearwise analysis

# %% [markdown]
# We will try to see the average no of people using hte service year by year

# %%
train.groupby('year')['Count'].sum()
# Out:
# year
# 2012      34932
# 2013     685968
# 2014    1820366
# Name: Count, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
train.groupby('year')['Count'].sum().plot.bar()
plt.title('Count Sum')
plt.xlabel('Year')
plt.ylabel('Count')
plt.subplot(2,2,2)
train.groupby('year')['Count'].mean().plot.bar()
plt.title('Count Mean')
plt.xlabel('Year')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# We can observe that the total passengrs and mean of the passengers in increasing.
#
# There is a drastic increase in the Year 2013-2014 compared to 2012-2013

# %%
train.groupby('month')['Count'].sum()
# Out:
# month
# 1     138112
# 2     149448
# 3     154442
# 4     198260
# 5     230722
# 6     268882
# 7     311098
# 8     365144
# 9     371196
# 10    112284
# 11    112916
# 12    128762
# Name: Count, dtype: int64

# %% [markdown]
# #### 2) Monthwise analysis

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
train.groupby('month')['Count'].sum().plot.bar()
plt.title('Count Sum')
plt.xlabel('Year')
plt.ylabel('Count')
plt.subplot(2,2,2)
train.groupby('month')['Count'].mean().plot.bar()
plt.title('Count Mean')
plt.xlabel('Year')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# From the above plot of Count vs Month we can observe the following:
#     - There is less traffic from the month of Jan to June.
#     - There is an increase in traffic from the month of July to October.
#     - Sudden decline the usage of the service in the months October to December.

# %%
plt.figure(figsize=(15,6))
train.groupby(['year', 'month'])['Count'].mean().plot.bar()
plt.ylabel("Mean Count")
plt.title("Year - Month Vs Count")
# Out:
# Text(0.5,1,'Year - Month Vs Count')

# %% [markdown]
# As observed in the plot of Count vs Month there was a decline in the count of passengers in the months.
# - From the above observation we can see that there is no data for the months Jan - July. This may be because the service was not provided during that time.
# - We do not have data for the Months of Oct - Dec for the year 2014. This is the reason for the decline of the count and mean values of usage in the months of Oct to December
# - If we observe the Mean values of the Months of Oct to December for the year 2013 we can see that an increasing Trand is being followed in those months too.

# %% [markdown]
# #### 3) Daywise Analysis

# %%
train.groupby('day')['Count'].mean().plot.bar()

# %% [markdown]
# #### 4) Hourly Analysis

# %%
train.groupby('hour')['Count'].sum().plot.bar()

# %% [markdown]
# We can observe that there is more surge during most hours of the day except for the morning hours

# %% [markdown]
# #### 5) Weekday/Weekend Analysis

# %%
train.groupby('day_of_week')['Count'].mean().plot.bar()

# %% [markdown]
# There is more traffic in the weekdays compared to the weekends

# %%
hourly = train.resample('H').mean()

# Converting to daily mean
daily = train.resample('D').mean()

# Converting to weekly mean
weekly = train.resample('W').mean()

# Converting to monthly mean
monthly = train.resample('M').mean()

# %%
fig, axs = plt.subplots(4,1)

hourly.Count.plot(figsize=(15,8), title= 'Hourly', fontsize=14, ax=axs[0])
daily.Count.plot(figsize=(15,8), title= 'Daily', fontsize=14, ax=axs[1])
weekly.Count.plot(figsize=(15,8), title= 'Weekly', fontsize=14, ax=axs[2])
monthly.Count.plot(figsize=(15,8), title= 'Monthly', fontsize=14, ax=axs[3])

plt.show()

# %% [markdown]
# ## Stationality

# %% [markdown]
# Before forecasting we will first check whether the time series is sattionary or not. This is because one of the pre-requisits for Time Series forcasting model is that the Time Series should be statonary.

# %% [markdown]
# To Test the Statinality we use the Dickey-Fuller Test.

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries,window):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=window).mean()
    rolstd = timeseries.rolling(window=window).std()

    #Plot rolling statistics:
    plt.figure(figsize=(15,5))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %% [markdown]
# The intuition behind this test is that it determines how strongly a time series is defined by a trend.
#
# - The Null hypothesis for the Dickey-Fuller Test is that the Time Series is not Stationary.
# - The alternative Hypothesis states that the Time Series is Stationary.
#
# So we will be looking to reject the null hypothesis. The p value of this test should be as low as possible so that we can reject the null hypothesis and say that the Time Series is Stationary.

# %%
test_stationarity(ts,24)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                    -4.456561
# p-value                            0.000235
# #Lags Used                        45.000000
# Number of Observations Used    18242.000000
# Critical Value (1%)               -3.430709
# Critical Value (5%)               -2.861698
# Critical Value (10%)              -2.566854
# dtype: float64

# %% [markdown]
# From the above output of the Dicket Fuller Test we can see that we have quite a small p-value which means that the time series is stationary. But still we can see an increasing trend. We can remove the trend and seasonality to make the time series more stationary

# %% [markdown]
# Since there is a visible trend in the TS we can take the log transform of the TS so that the values come closer to each other and we can spot the trend

# %%
plt.figure(figsize=(15,5))
ts_log = np.log(ts)
plt.plot(ts_log)

# %%
test_stationarity(ts_log,25)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                    -3.211373
# p-value                            0.019336
# #Lags Used                        45.000000
# Number of Observations Used    18242.000000
# Critical Value (1%)               -3.430709
# Critical Value (5%)               -2.861698
# Critical Value (10%)              -2.566854
# dtype: float64

# %% [markdown]
# After taking the log transform we can see that the p-value has increased and also we can see the upward trend in the plot.
#
# Next we will be calculation the Rolling mean/Moving Average of the Time Series. Rolling mean is a statistic checks how the Mean and SD changes with time.
#
# Rolling mean is calaulated

# %% [markdown]
# #### Removing Moving Average / Trend

# %%
rolmean = ts_log.rolling(window=25).mean()

# %% [markdown]
# Subtracting the Rolling mean from the TS

# %%
Train_2 = ts_log-rolmean
Train_2.dropna(axis=0,inplace=True)
test_stationarity(Train_2,24)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -21.267255
# p-value                            0.000000
# #Lags Used                        45.000000
# Number of Observations Used    18218.000000
# Critical Value (1%)               -3.430709
# Critical Value (5%)               -2.861699
# Critical Value (10%)              -2.566854
# dtype: float64

# %% [markdown]
# Splitting the Train Dataset into 2 so as to verify our model.

# %%
Train=train.ix['2012-08-25':'2014-06-24']
valid=train.ix['2014-06-25':'2014-09-25']

# %%
Train_log = np.log(Train['Count'])
valid_log = np.log(valid['Count'])

# %%
plt.figure(figsize=(15,5))
moving_avg = Train_log.rolling(25).mean()
plt.plot(Train_log)
plt.plot(moving_avg, color = 'red')
plt.show()

# %% [markdown]
# Removing Trend

# %%
train_log_moving_avg_diff = Train_log - moving_avg
train_log_moving_avg_diff.shape
Train_log.shape
# Out:
# (16056,)

# %%
train_log_moving_avg_diff.dropna(inplace = True)
test_stationarity(train_log_moving_avg_diff,24)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -22.532152
# p-value                            0.000000
# #Lags Used                        43.000000
# Number of Observations Used    15988.000000
# Critical Value (1%)               -3.430759
# Critical Value (5%)               -2.861721
# Critical Value (10%)              -2.566866
# dtype: float64

# %% [markdown]
# #### Removing Seasonality

# %% [markdown]
# Seasonality can be of two types:
#     - Multiplicative
#     - Additive

# %% [markdown]
# Seasonaltiy can be removed in two ways
#     - Decomposition
#     - Differencing

# %% [markdown]
# Here we will be taking the First order differencing to remove Seasonality from the Time Series.
#
# We are using the shift() function to do the first order differencing

# %%
train_log_diff = Train_log - Train_log.shift(1)
test_stationarity(train_log_diff.dropna(),25)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -28.579381
# p-value                            0.000000
# #Lags Used                        43.000000
# Number of Observations Used    16011.000000
# Critical Value (1%)               -3.430758
# Critical Value (5%)               -2.861721
# Critical Value (10%)              -2.566866
# dtype: float64

# %% [markdown]
# From the Above results and plot we can see that the Time Series is Stationary now. There is no Trend or Seasonality presint in the Time Series

# %% [markdown]
# Now we will be decomposing the Time Series into:
#     - Trend
#     - Seasonality
#     - Noise

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(pd.DataFrame(Train_log).Count.values, freq = 24)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
plt.figure(figsize=(15,10))
plt.subplot(411)
plt.plot(Train_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# We can see the trend, residuals and the seasonality clearly in the above graph. Seasonality shows a constant trend in counter.

# %% [markdown]
# #### Residuals Stationarity Test

# %%
train_log_decompose = pd.DataFrame(residual)
train_log_decompose['date'] = Train_log.index
train_log_decompose.set_index('date', inplace = True)
train_log_decompose.dropna(inplace=True)
test_stationarity(train_log_decompose[0],25)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -31.326116
# p-value                            0.000000
# #Lags Used                        43.000000
# Number of Observations Used    15988.000000
# Critical Value (1%)               -3.430759
# Critical Value (5%)               -2.861721
# Critical Value (10%)              -2.566866
# dtype: float64

# %% [markdown]
# ## Forecasting the time series using ARIMA

# %%
from statsmodels.tsa.stattools import acf, pacf
lag_acf = acf(train_log_diff.dropna(), nlags=25)
lag_pacf = pacf(train_log_diff.dropna(), nlags=25, method='ols')

# %%
plt.figure(figsize=(10,10))
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(train_log_diff.dropna())),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(train_log_diff.dropna())),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(train_log_diff.dropna())),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(train_log_diff.dropna())),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(Train_log, order=(2, 1, 0))  # here the q value is zero since it is just the AR model
results_AR = model.fit(disp=-1)
plt.figure(figsize=(15,5))
plt.plot(train_log_diff.dropna(), label='original')
plt.plot(results_AR.fittedvalues, color='red', label='predictions')
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\nitis\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\nitis\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)

# %%
AR_predict=results_AR.predict(start="2014-06-25", end="2014-09-25")
AR_predict=AR_predict.cumsum().shift().fillna(0)
AR_predict1=pd.Series(np.ones(valid.shape[0]) * np.log(valid['Count'])[0], index = valid.index)
AR_predict1=AR_predict1.add(AR_predict,fill_value=0)
AR_predict = np.exp(AR_predict1)

# %%
plt.figure(figsize=(15,5))
plt.plot(valid['Count'], label = "Valid")
plt.plot(AR_predict, color = 'red', label = "Predict")
plt.legend(loc= 'best')
plt.title('RMSE: %.4f'% (np.sqrt(np.dot(AR_predict, valid['Count']))/valid.shape[0]))
plt.show()

# %%
plt.figure(figsize=(15,5))
model = ARIMA(Train_log, order=(0, 1, 2))  # here the p value is zero since it is just the MA model
results_MA = model.fit(disp=-1)  
plt.plot(train_log_diff.dropna(), label='original')
plt.plot(results_MA.fittedvalues, color='red', label='prediction')
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\nitis\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\nitis\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)

# %%
MA_predict=results_MA.predict(start="2014-06-25", end="2014-09-25")
MA_predict=MA_predict.cumsum().shift().fillna(0)
MA_predict1=pd.Series(np.ones(valid.shape[0]) * np.log(valid['Count'])[0], index = valid.index)
MA_predict1=MA_predict1.add(MA_predict,fill_value=0)
MA_predict = np.exp(MA_predict1)

# %%
plt.figure(figsize=(15,5))
plt.plot(valid['Count'], label = "Valid")
plt.plot(MA_predict, color = 'red', label = "Predict")
plt.legend(loc= 'best')
plt.title('RMSE: %.4f'% (np.sqrt(np.dot(MA_predict, valid['Count']))/valid.shape[0]))
plt.show()

# %%
model = ARIMA(Train_log, order=(2, 1, 2))  
results_ARIMA = model.fit(disp=-1)  
plt.plot(train_log_diff.dropna(),  label='original')
plt.plot(results_ARIMA.fittedvalues, color='red', label='predicted')
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\nitis\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\nitis\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)

# %%
def check_prediction_diff(predict_diff, given_set):
    predict_diff= predict_diff.cumsum().shift().fillna(0)
    predict_base = pd.Series(np.ones(given_set.shape[0]) * np.log(given_set['Count'])[0], index = given_set.index)
    predict_log = predict_base.add(predict_diff,fill_value=0)
    predict = np.exp(predict_log)
    plt.figure(figsize=(15,5))
    plt.plot(given_set['Count'], label = "Given set")
    plt.plot(predict, color = 'red', label = "Predict")
    plt.legend(loc= 'best')
    plt.title('RMSE: %.4f'% (np.sqrt(np.dot(predict, given_set['Count']))/given_set.shape[0]))
    plt.show()

# %%
def check_prediction_log(predict_log, given_set):
    predict = np.exp(predict_log)
    plt.figure(figsize=(15,5))
    plt.plot(given_set['Count'], label = "Given set")
    plt.plot(predict, color = 'red', label = "Predict")
    plt.legend(loc= 'best')
    plt.title('RMSE: %.4f'% (np.sqrt(np.dot(predict, given_set['Count']))/given_set.shape[0]))
    plt.show()

# %%
ARIMA_predict_diff=results_ARIMA.predict(start="2014-06-25", end="2014-09-25")

# %%
check_prediction_diff(ARIMA_predict_diff, valid)

# %%
def cv(ts,nsplits):
    for train_index, test_index in tscv.split(X):
        from sklearn.model_selection import TimeSeriesSplit
        tscv = TimeSeriesSplit(n_splits=nsplits)
        print("Train:", train_index, "Validation:", val_index)
        X_train, X_test = X[train_index], X[val_index]
        y_train, y_test = y[train_index], y[val_index]
